# %% [markdown]
# ## Importing The Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing the dataset

# %%
data = pd.read_csv("wine_dataset.csv")
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ## Data Quality Check

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ### Checking for Null values

# %%
data.isnull()                                                           # Checking for cells having null values
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# 5             False             False        False           False      False
# 6             False             False        False           False      False
# 7             False             False        False           False      False
# 8             False             False        False           False      False
# 9             False             False        False           False      False
# 10            False             False        False           False      False
# ...

# %%
data.isnull().sum().sum()                           # There are no missing values in data frame
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.columns = ["fixed_acidity","volatile_acidity","citric_acid","residual_sugar","chlorides","free_sulfur_dioxide","total_sulfur_dioxide","density","ph","sulphates","alcohol","quality"]

# %%
data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ### Histograms

# %%
sns.set_style("darkgrid")
plt.hist(data.volatile_acidity,edgecolor='black',linewidth = 1.5 ,bins=15)
plt.title("Volatile Acidity")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(data.citric_acid,edgecolor='black',linewidth = 1.5 ,bins=15)
plt.title("Citric Acid")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(data.residual_sugar,edgecolor='black',linewidth = 1.5 ,bins=15)
plt.title("Residual Sugar")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(data.total_sulfur_dioxide,edgecolor='black',linewidth = 1.5 ,bins=15)
plt.title("total_sulfur_dioxide")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(data.free_sulfur_dioxide,edgecolor='black',linewidth = 1.5 ,bins=15)
plt.title("free_sulfur_dioxide")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Boxplots

# %%
for column in data:
    plt.figure(figsize = (15,10))
    data.boxplot([column])

# %% [markdown]
# ### Bivariate Analysis

# %%
data.head(5)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ### Scatterplots

# %%
sns.set_style('white')
plt.scatter(data.volatile_acidity,data.quality)
plt.show()

# %%
plt.scatter(data.fixed_acidity,data.quality,c='black')
plt.show()

# %%
plt.scatter(data.residual_sugar,data.quality,c='red')
plt.show()

# %%
plt.scatter(data.chlorides,data.quality,c='blue')
plt.show()

# %%
plt.scatter(data.free_sulfur_dioxide,data.quality,c='black')
plt.show()

# %%
plt.scatter(data.total_sulfur_dioxide,data.quality,c='red')
plt.show()

# %% [markdown]
# ## Modelling

# %%
data.head(5)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ### Importing the libraries

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Splitting the dataset

# %%
x = data.iloc[:,:-1].values                                          # creating the matrix of features
y = data.iloc[:,-1].values
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.2,random_state = 5)

# %% [markdown]
# ### Applying KNN Classification Algorithm

# %%
knn = KNeighborsClassifier(n_neighbors = 3)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %% [markdown]
# ### Prediction

# %%
y_pred = knn.predict(x_test)
y_pred
# Out:
# array([6, 3, 5, 6, 5, 6, 5, 5, 6, 5, 6, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5,
#        6, 6, 6, 5, 6, 6, 7, 5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 5, 6, 5, 6, 5,
#        6, 6, 5, 6, 6, 5, 7, 6, 5, 6, 6, 5, 6, 6, 6, 6, 5, 6, 7, 5, 5, 5,
#        6, 6, 7, 6, 6, 7, 6, 5, 6, 6, 5, 6, 5, 6, 7, 6, 6, 6, 4, 5, 6, 5,
#        5, 5, 6, 6, 5, 6, 5, 5, 6, 6, 6, 7, 6, 6, 5, 6, 6, 6, 6, 5, 5, 5,
#        6, 6, 6, 5, 6, 5, 5, 5, 5, 6, 6, 6, 7, 6, 5, 5, 5, 5, 5, 6, 5, 5,
#        6, 6, 5, 5, 5, 6, 5, 6, 6, 5, 5, 7, 7, 5, 5, 5, 6, 6, 5, 5, 5, 5,
#        5, 5, 5, 6, 5, 5, 6, 5, 5, 6, 6, 5, 5, 5, 6, 5, 5, 6, 5, 5, 6, 5,
#        5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 5, 5, 7, 6, 5, 5, 6, 6, 5, 5, 6, 6,
#        5, 5, 6, 6, 5, 6, 5, 5, 6, 6, 5, 5, 5, 6, 6, 5, 6, 5, 6, 6, 5, 5,
#        6, 5, 6, 5, 5, 5, 6, 5, 5, 5, 6, 6, 6, 5, 5, 5, 5, 5, 7, 6, 5, 5,
#        5, 6, 5, 5, 5, 6, 5, 6, 6, 6, 5, 6, 6, 6, 5, 5, 7, 6, 5, 6, 6, 5,
#        5, 4, 5, 5, 5, 5, 5, 7, 6, 6, 7, 7, 6, 5, 5, 6, 6, 7, 5, 5, 5, 6,
# ...

# %% [markdown]
# ### Accuracy check

# %%
print(knn.score(x_test,y_test))
# Out:
# 0.571875
